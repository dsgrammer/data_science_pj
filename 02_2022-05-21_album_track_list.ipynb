# %% [markdown]
# This file iterates over a csv of an album list (generated by the artist list file) to output all the track information for each album in the list.

# %%
import requests
import pandas as pd
import time

# %%
AUTH_URL = 'https://accounts.spotify.com/api/token'
# POST
auth_response = requests.post(AUTH_URL, {
    'grant_type': 'client_credentials',
    'client_id': '9cdef0bc741e471385b100af843c28c5',
    'client_secret': 'a0820dd07a3e4d8facb51bb5ed5130a2',
})
# convert the response to JSON
auth_response_data = auth_response.json()
# save the access token
access_token = auth_response_data['access_token']
# used for authenticating all API calls
headers = {'Authorization': 'Bearer {token}'.format(token=access_token)}

# %%
#get album details
def get_album_details(track_df,album_id):
    # pull all tracks from this album
    for album in album_id:
        album_id = album
        r = requests.get(BASE_URL + 'albums/' + album_id + '/tracks', 
                         headers=headers)
        d = r.json()
        time.sleep(1)
        
        i = 0
        for track in d['items']:
            if track['type'] == 'track':
                track_id = d['items'][i]['id']
                track_name = d['items'][i]['name']
                duration_ms = d['items'][i]['duration_ms']
                explicit = d['items'][i]['explicit']
                
                #save data in pd dataframe
                ##track_df = track_df.append({'album_id':album_id,'track_id': track_id,'track_name': track_name,
                ##                            'duration_ms': duration_ms,'explicit': explicit},ignore_index=True)
                temp_df = pd.DataFrame({'album_id':album_id,'track_id': track_id,'track_name': track_name,
                                        'duration_ms': duration_ms,'explicit': explicit},index=[i])
                track_df = pd.concat([track_df, temp_df], ignore_index=True)
            i += 1
    return track_df

# %%
#Main
BASE_URL = 'https://api.spotify.com/v1/'
album_df = pd.read_csv(r'C:\Users\dsgra\OneDrive\Documents\01 - Full Stack Data Science PJ\data science pj\album_list.csv')
album_id = album_df.loc[:,'album_id']
track_df = pd.DataFrame(columns=["album_id","track_id","track_name","duration_ms","explicit"])
track_df = get_album_details(track_df, album_id)

track_df.to_csv(r'C:\Users\dsgra\OneDrive\Documents\01 - Full Stack Data Science PJ\data science pj\track_list.csv',encoding='utf-8-sig')
print('-----------------------------------')
print('Saved to .csv in project directory.')
print('-----------------------------------')
# Out:
# -----------------------------------
# -----------------------------------
# Saved to .csv in project directory.
# -----------------------------------
# -----------------------------------

# %%
track_df
# Out:
#                    album_id                track_id  \
# 0    0mrtkWYrUzTuFwyiiQPdQs  4Tf5QqoJWl9jjHrK6zwT0i
# 1    0mrtkWYrUzTuFwyiiQPdQs  1N8HMQL90GFdDaFUz6ONcs
# 2    0mrtkWYrUzTuFwyiiQPdQs  5YhmiVbhzLVP9aA20scJCs
# 3    0mrtkWYrUzTuFwyiiQPdQs  1c7kZbuNixEsCMbU3MZFpy
# 4    0mrtkWYrUzTuFwyiiQPdQs  07ELgtGISbYc3CavN1AcfX
# ..                      ...                     ...
# 254  1BRtQtljRJIxroJXI20K39  1ZfnGTUnha3QHj3KFmub0W
# 255  1BRtQtljRJIxroJXI20K39  2jCXj0T4qUGmLclOQTSKed
# 256  1BRtQtljRJIxroJXI20K39  4UnHhV70A2nwlmtpmNZqaf
# 257  1BRtQtljRJIxroJXI20K39  1xRloL4YOvq7HatNJOh5pk
# 258  1BRtQtljRJIxroJXI20K39  6XnjQ9NtfWjfnQjbwjDz4V
#
#                      track_name duration_ms explicit
# 0                             X       87557    False
# 1    In The Court Of The Dragon      309029    False
# 2    Like A Sword Over Damocles      330126    False
# 3                 Feast Of Fire      258837    False
# 4        A Crisis Of Revelation      335792    False
# ..                          ...         ...      ...
# 254                        Cafo      401120    False
# 255                   Inamorata      368080    False
# 256              Point to Point      104173    False
# 257                 Modern Meat      126520    False
# 258             Song of Solomon      256586    False
#
# [259 rows x 5 columns]
